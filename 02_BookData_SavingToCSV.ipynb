# %% [markdown]
# ## Summary
#
# - Scraped data from 50 pages of the Books to Scrape website
# - Collected book title, price, rating, and availability
# - Saved the data into a CSV file for database storage and analysis

# %%
import pandas as pd

# %%
df = pd.DataFrame(books_data)
df.to_csv("data/books.csv", index=False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame(books_data)
#       2 df.to_csv("data/books.csv", index=False)
#       3 df.head()
#
# NameError: name 'pd' is not defined
